# %% [markdown]
# ## Baseline model

# %%
import matplotlib.pyplot as plt
import numpy as np
import gym
# %matplotlib inline

# %%
# These functions allow us to preprocess 
# original images from size of 210x160x3 
# to size of 110x84 (grayscale images).

import theano
from PIL import Image

def preprocess(image):
    def_h = 84
    def_w = 110
    img = 0.299*image[:,:,0] + 0.587*image[:,:,1] + 0.114*image[:,:,2]
    
    img = Image.fromarray(img).resize((def_h, def_w))
    
    img = np.expand_dims(img, axis=2)
    return img

def preprocess_tensor(tensor):
    def_h = 84
    def_w = 110
    tnsr = np.zeros((tensor.shape[0], tensor.shape[1], def_w, def_h, 1),dtype=theano.config.floatX)
    for i in xrange(tensor.shape[0]):
        for j in xrange(tensor.shape[1]):
            img = 0.299*tensor[i,j,:,:,0] + 0.587*tensor[i,j,:,:,1] + 0.114*tensor[i,j,:,:,2]
            tnsr[i,j,:,:,0] = Image.fromarray(img).resize((def_h, def_w))
    return tnsr

def preprocess_tensor4(tensor):
    def_h = 84
    def_w = 110
    tnsr = np.zeros((tensor.shape[0], def_w, def_h, 1),dtype=theano.config.floatX)
    for i in xrange(tensor.shape[0]):
        img = 0.299*tensor[i,:,:,0] + 0.587*tensor[i,:,:,1] + 0.114*tensor[i,:,:,2]
        tnsr[i,:,:,0] = Image.fromarray(img).resize((def_h, def_w))
    return tnsr

# %% [markdown]
# ### Game Parameters

# %%
experiment_setup_name = "tutorial.gym.atari.MsPacman-v0.cnn"
GAME_TITLE = 'MsPacman-v0'
N_PARALLEL_GAMES = 20
replay_seq_len = 50

atari = gym.make(GAME_TITLE)
atari.reset()
n_actions = atari.action_space.n
observation_shape = (None,) + (110, 84, 1)
action_names = ['NOOP', 'UP', 'RIGHT', 'LEFT', 'DOWN', 'UPRIGHT', 'UPLEFT', 'DOWNRIGHT', 'DOWNLEFT']
print action_names
# Out:
# ['NOOP', 'UP', 'RIGHT', 'LEFT', 'DOWN', 'UPRIGHT', 'UPLEFT', 'DOWNRIGHT', 'DOWNLEFT']

# %%
observation_shape
# Out:
# (None, 110, 84, 1)

# %%
del atari

# %% [markdown]
# ### Observations

# %%
import lasagne
from lasagne.layers import InputLayer, DimshuffleLayer

observation_layer = InputLayer(observation_shape, name="images input")
observation_reshape = DimshuffleLayer(observation_layer,(0,3,1,2))

# %% [markdown]
# ### Memory layer

# %%
from agentnet.memory import WindowAugmentation
window_size = 5

prev_window = InputLayer((None,window_size)+tuple(observation_reshape.output_shape[1:]),
                        name = "previous window state")

window = WindowAugmentation(observation_reshape,
                            prev_window,
                            name = "new window state")

memory_dict = {window:prev_window}

# %% [markdown]
# ### Policy

# %%
from lasagne.layers import ExpressionLayer, DenseLayer

window_max = ExpressionLayer(window,
                             lambda a: a.max(axis=1),
                             output_shape = (None,)+window.output_shape[2:])

nn = lasagne.layers.Conv2DLayer(window_max, num_filters=16, filter_size=(8, 8), stride=(4, 4))
nn = lasagne.layers.BatchNormLayer(nn)
nn = lasagne.layers.Conv2DLayer(nn, num_filters=32, filter_size=(4, 4), stride=(2, 2))
nn = lasagne.layers.BatchNormLayer(nn)
nn = lasagne.layers.DenseLayer(nn, num_units=256)
nn = lasagne.layers.BatchNormLayer(nn)

# %% [markdown]
# ### Resolver

# %%
from agentnet.resolver import EpsilonGreedyResolver

q_eval = DenseLayer(nn,
                   num_units = n_actions,
                   nonlinearity=lasagne.nonlinearities.linear,
                   name="QEvaluator")
resolver = EpsilonGreedyResolver(q_eval,name="resolver")

# %% [markdown]
# ### Putting it together

# %%
from agentnet.agent import Agent
agent = Agent(observation_layer,
              memory_dict,
              q_eval,resolver)


weights = lasagne.layers.get_all_params(resolver,trainable=True)
weights
# Out:
# [W,
#  b,
#  beta,
#  gamma,
#  W,
#  b,
#  beta,
#  gamma,
#  W,
#  b,
#  beta,
#  gamma,
#  QEvaluator.W,
#  QEvaluator.b]

# %% [markdown]
# ### Step function

# %%
applier_fun = agent.get_react_function()

def step(observation, prev_memories = 'zeros', batch_size = N_PARALLEL_GAMES):
    """ returns actions and new states given observation and prev state
    Prev state in default setup should be [prev window,]"""

    if prev_memories == 'zeros':
        prev_memories = agent.get_zeros_like_memory(batch_size=batch_size)
    
    obs = preprocess_tensor4(np.array(observation))
    if len(np.array(prev_memories).shape) == 5:
        res = applier_fun(obs, *[prev_memories])
    else:
        res = applier_fun(obs, *prev_memories)
    
    action = res[0]
    memories = res[1:]
    return action, memories[0]

# %% [markdown]
# ### Environment, pool and all other stuff

# %%
from agentnet.experiments.openai_gym.pool import EnvPool

pool = EnvPool(agent, n_games=N_PARALLEL_GAMES, make_env=GAME_TITLE, agent_step=step)
# Out:
# [2017-05-22 16:14:30,179] Making new env: MsPacman-v0
# [2017-05-22 16:14:30,393] Making new env: MsPacman-v0
# [2017-05-22 16:14:30,601] Making new env: MsPacman-v0
# [2017-05-22 16:14:30,806] Making new env: MsPacman-v0
# [2017-05-22 16:14:31,007] Making new env: MsPacman-v0
# [2017-05-22 16:14:31,262] Making new env: MsPacman-v0
# [2017-05-22 16:14:31,492] Making new env: MsPacman-v0
# [2017-05-22 16:14:31,718] Making new env: MsPacman-v0
# [2017-05-22 16:14:31,980] Making new env: MsPacman-v0
# [2017-05-22 16:14:32,219] Making new env: MsPacman-v0
# [2017-05-22 16:14:32,423] Making new env: MsPacman-v0
# [2017-05-22 16:14:32,628] Making new env: MsPacman-v0
# [2017-05-22 16:14:32,853] Making new env: MsPacman-v0
# [2017-05-22 16:14:33,074] Making new env: MsPacman-v0
# [2017-05-22 16:14:33,293] Making new env: MsPacman-v0
# [2017-05-22 16:14:33,526] Making new env: MsPacman-v0
# [2017-05-22 16:14:33,729] Making new env: MsPacman-v0
# [2017-05-22 16:14:33,949] Making new env: MsPacman-v0
# [2017-05-22 16:14:34,213] Making new env: MsPacman-v0
# [2017-05-22 16:14:34,452] Making new env: MsPacman-v0

# %%
# %%time
observation_log,action_log,reward_log,_,_,_  = pool.interact(50)

print(np.array(action_names)[np.array(action_log)[:3,:5]])
# Out:
# /Users/vlad/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:11: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# [['LEFT' 'DOWNLEFT' 'DOWNLEFT' 'RIGHT' 'RIGHT']
#  ['LEFT' 'DOWNLEFT' 'NOOP' 'UPRIGHT' 'DOWN']
#  ['LEFT' 'DOWNLEFT' 'DOWNLEFT' 'NOOP' 'RIGHT']]
# CPU times: user 2.45 s, sys: 651 ms, total: 3.1 s
# Wall time: 3.03 s

# %%
from agentnet.environment import SessionPoolEnvironment
env = SessionPoolEnvironment(observations = observation_layer,
                             actions=resolver,
                             agent_memories=agent.agent_states)

def update_pool(env, pool,n_steps=100):
    """ a function that creates new sessions and ads them into the pool
    throwing the old ones away entirely for simplicity"""

    preceding_memory_states = list(pool.prev_memory_states)
    
    observation_tensor,action_tensor,reward_tensor,_,is_alive_tensor,_= pool.interact(n_steps=n_steps)
    observation_tensor = preprocess_tensor(observation_tensor)
    
    env.load_sessions(observation_tensor,action_tensor,reward_tensor,is_alive_tensor,preceding_memory_states)
    
update_pool(env,pool,replay_seq_len)
# Out:
# /Users/vlad/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:11: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison

# %% [markdown]
# ### Loss

# %%
from agentnet.learning import qlearning
from lasagne.regularization import regularize_network_params, l2

#get agent's Qvalues obtained via experience replay
_,_,_,_,qvalues_seq = agent.get_sessions(
    env,
    session_length=replay_seq_len,
    batch_size=env.batch_size,
    optimize_experience_replay=True,
)

scaled_reward_seq = env.rewards
elwise_mse_loss = qlearning.get_elementwise_objective(qvalues_seq,
                                                        env.actions[0],
                                                        scaled_reward_seq,
                                                        env.is_alive,
                                                        n_steps=10,
                                                        gamma_or_gammas=0.99,)

#compute mean over "alive" fragments
mse_loss = elwise_mse_loss.sum() / env.is_alive.sum()
reg_l2 = regularize_network_params(resolver,l2)*10**-4
loss = mse_loss + reg_l2

updates = lasagne.updates.adadelta(loss,weights,learning_rate=0.01)

mean_session_reward = env.rewards.sum(axis=1).mean()

# %%
import theano
train_fun = theano.function([],[loss,mean_session_reward],updates=updates)
evaluation_fun = theano.function([],[loss,mse_loss,reg_l2,mean_session_reward])

# %% [markdown]
# ### Training

# %%
def display_sessions(max_n_sessions = 3):
    """just draw random images"""
    
    plt.figure(figsize=[15,8])
    
    pictures = [atari.render("rgb_array") for atari in pool.envs[:max_n_sessions]]
    for i,pic in enumerate(pictures):
        plt.subplot(1,max_n_sessions,i+1)
        plt.imshow(pic)
    plt.show()

#visualize untrained network performance (which is mostly random)
display_sessions()

# %%
import os
from agentnet.display import Metrics

score_log = Metrics()
epoch_counter = 1
alpha = 0.1
ma_reward_current = 0.
ma_reward_greedy = 0.

# %%
# %%time

n_epochs = 10000

for i in range(n_epochs):    
    #train
    update_pool(env,pool,replay_seq_len)
    resolver.rng.seed(i)    
    loss,avg_reward = train_fun()
    
    ##update resolver's epsilon (chance of random action instead of optimal one)
    if epoch_counter%1 ==0:
        current_epsilon = 0.05 + 0.45*np.exp(-epoch_counter/1000.)
        resolver.epsilon.set_value(np.float32(current_epsilon))
    
    ##record current learning progress and show learning curves
    if epoch_counter%10 ==0:

        ##update learning curves
        full_loss, q_loss, l2_penalty, avg_reward_current = evaluation_fun()
        ma_reward_current = (1-alpha)*ma_reward_current + alpha*avg_reward_current
        score_log["expected e-greedy reward"][epoch_counter] = ma_reward_current
        
        #greedy train
        resolver.epsilon.set_value(0)
        update_pool(env,pool,replay_seq_len)

        avg_reward_greedy = evaluation_fun()[-1]
        ma_reward_greedy = (1-alpha)*ma_reward_greedy + alpha*avg_reward_greedy
        score_log["expected greedy reward"][epoch_counter] = ma_reward_greedy
        
        #back to epsilon-greedy
        resolver.epsilon.set_value(np.float32(current_epsilon))
        update_pool(env,pool,replay_seq_len)

        print("epoch %i,loss %.5f, epsilon %.5f, rewards: ( e-greedy %.5f, greedy %.5f) "%(
            epoch_counter,full_loss,current_epsilon,ma_reward_current,ma_reward_greedy))
        print("rec %.3f reg %.3f"%(q_loss,l2_penalty))

    if epoch_counter %100 ==0:
        print("Learning curves:")
        score_log.plot()


        print("Random session examples")
        display_sessions()
    
    #run several sessions of game, record videos and save obtained results
    if epoch_counter %1000 ==0:
        
        save_path = 'videos/MSPacman-v0_' + str(epoch_counter)

        subm_env = gym.make(GAME_TITLE)
        subm_env = gym.wrappers.Monitor(subm_env, 'videos/', force=True)

        rws = []

        for i_episode in xrange(10):

            #initial observation
            observation = subm_env.reset()
            #initial memory
            prev_memories = "zeros"

            s_reward =0.
            t = 0
            while True:

                action,new_memories = step([observation],prev_memories,batch_size=1)
                observation, reward, done, info = subm_env.step(action[0])

                s_reward += reward

                prev_memories = new_memories
                if done:
                    print("Episode finished after {} timesteps, rw = {}".format(t+1,s_reward))
                    rws.append(s_reward)
                    break
                t+=1

        subm_env.close()

        rws = np.array(rws)
        print("Mean {}, Var {}".format(np.mean(rws), np.var(rws)))
        np.savez(open('rws4hist_'+str(epoch_counter)+'.npz', 'wb'), rws=rws)
        
        
    epoch_counter  +=1

    
# Time to drink some coffee!
# Out:
# /Users/vlad/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:11: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# epoch 11850,loss 961.07117, epsilon 0.05000, rewards: ( e-greedy 63.39636, greedy 51.22001)
# rec 960.978 reg 0.093
# epoch 11860,loss 229.48343, epsilon 0.05000, rewards: ( e-greedy 63.40673, greedy 53.19801)
# rec 229.390 reg 0.093
# epoch 11870,loss 866.87317, epsilon 0.05000, rewards: ( e-greedy 65.16605, greedy 56.57821)
# rec 866.780 reg 0.093
# epoch 11880,loss 392.10988, epsilon 0.05000, rewards: ( e-greedy 62.89945, greedy 54.97039)
# rec 392.016 reg 0.093
# epoch 11890,loss 506.12377, epsilon 0.05000, rewards: ( e-greedy 61.50950, greedy 56.02335)
# rec 506.030 reg 0.093
# epoch 11900,loss 1105.79587, epsilon 0.05000, rewards: ( e-greedy 62.55855, greedy 58.87101)
# rec 1105.702 reg 0.094
# Learning curves:
# Random session examples
# epoch 11910,loss 521.03108, epsilon 0.05000, rewards: ( e-greedy 61.15270, greedy 56.53391)
# rec 520.938 reg 0.094
# epoch 11920,loss 728.04017, epsilon 0.05000, rewards: ( e-greedy 60.13743, greedy 54.13052)
# rec 727.947 reg 0.094
# epoch 11930,loss 197.63056, epsilon 0.05000, rewards: ( e-greedy 57.42369, greedy 51.61747)
# rec 197.537 reg 0.094
# epoch 11940,loss 451.94793, epsilon 0.05000, rewards: ( e-greedy 57.53132, greedy 56.35572)
# rec 451.854 reg 0.094
# epoch 11950,loss 344.47069, epsilon 0.05000, rewards: ( e-greedy 57.67819, greedy 57.37015)
# rec 344.377 reg 0.094
# epoch 11960,loss 367.19510, epsilon 0.05000, rewards: ( e-greedy 57.01037, greedy 57.38313)
# rec 367.102 reg 0.094
# epoch 11970,loss 241.60040, epsilon 0.05000, rewards: ( e-greedy 56.30933, greedy 58.19482)
# rec 241.507 reg 0.094
# epoch 11980,loss 472.67066, epsilon 0.05000, rewards: ( e-greedy 55.17840, greedy 57.42534)
# rec 472.577 reg 0.094
# epoch 11990,loss 170.06354, epsilon 0.05000, rewards: ( e-greedy 53.71056, greedy 55.23280)
# rec 169.970 reg 0.094
# epoch 12000,loss 1415.52414, epsilon 0.05000, rewards: ( e-greedy 54.33950, greedy 58.85952)
# rec 1415.431 reg 0.094
# Learning curves:
# Random session examples
# [2017-05-23 14:22:48,546] Making new env: MsPacman-v0
# [2017-05-23 14:22:48,873] Clearing 8 monitor files from previous run (because force=True was provided)
# [2017-05-23 14:22:48,887] Starting new video recorder writing to /Users/vlad/Desktop/DL_SK/Project/videos/openaigym.video.11.72356.video000000.mp4
# [2017-05-23 14:22:52,734] Starting new video recorder writing to /Users/vlad/Desktop/DL_SK/Project/videos/openaigym.video.11.72356.video000001.mp4
# Episode finished after 824 timesteps, rw = 840.0
# Episode finished after 853 timesteps, rw = 540.0
# Episode finished after 690 timesteps, rw = 70.0
# Episode finished after 968 timesteps, rw = 440.0
# Episode finished after 917 timesteps, rw = 840.0
# Episode finished after 1586 timesteps, rw = 690.0
# Episode finished after 1032 timesteps, rw = 840.0
# [2017-05-23 14:23:16,537] Starting new video recorder writing to /Users/vlad/Desktop/DL_SK/Project/videos/openaigym.video.11.72356.video000008.mp4
# Episode finished after 793 timesteps, rw = 250.0
# Episode finished after 671 timesteps, rw = 140.0
# [2017-05-23 14:23:22,354] Finished writing results. You can upload them to the scoreboard via gym.upload('/Users/vlad/Desktop/DL_SK/Project/videos')
# Episode finished after 984 timesteps, rw = 440.0
# Mean 509.0, Var 76789.0
# epoch 12010,loss 1696.74855, epsilon 0.05000, rewards: ( e-greedy 57.30555, greedy 58.47357)
# rec 1696.655 reg 0.094
# epoch 12020,loss 489.72230, epsilon 0.05000, rewards: ( e-greedy 56.82500, greedy 57.22621)
# rec 489.629 reg 0.094
# epoch 12030,loss 184.22996, epsilon 0.05000, rewards: ( e-greedy 55.29250, greedy 58.05359)
# rec 184.136 reg 0.094
# epoch 12040,loss 328.85734, epsilon 0.05000, rewards: ( e-greedy 54.06325, greedy 57.59823)
# rec 328.764 reg 0.094
# epoch 12050,loss 247.84932, epsilon 0.05000, rewards: ( e-greedy 53.75692, greedy 57.83841)
# rec 247.756 reg 0.094
# epoch 12060,loss 462.85565, epsilon 0.05000, rewards: ( e-greedy 53.88123, greedy 57.75457)
# rec 462.762 reg 0.094
# epoch 12070,loss 1048.88754, epsilon 0.05000, rewards: ( e-greedy 54.64311, greedy 59.42911)
# rec 1048.794 reg 0.094
# epoch 12080,loss 901.70228, epsilon 0.05000, rewards: ( e-greedy 56.77880, greedy 59.23620)
# rec 901.609 reg 0.094
# epoch 12090,loss 333.30569, epsilon 0.05000, rewards: ( e-greedy 56.00092, greedy 56.86258)
# rec 333.212 reg 0.094
# epoch 12100,loss 243.82456, epsilon 0.05000, rewards: ( e-greedy 56.85083, greedy 54.07632)
# rec 243.731 reg 0.094
# Learning curves:
# Random session examples
# epoch 12110,loss 472.22781, epsilon 0.05000, rewards: ( e-greedy 57.96574, greedy 54.81869)
# rec 472.134 reg 0.094
# epoch 12120,loss 152.72651, epsilon 0.05000, rewards: ( e-greedy 53.86917, greedy 52.88682)
# rec 152.633 reg 0.094
# epoch 12130,loss 191.63385, epsilon 0.05000, rewards: ( e-greedy 53.93225, greedy 52.79814)
# rec 191.540 reg 0.094
# epoch 12140,loss 439.27625, epsilon 0.05000, rewards: ( e-greedy 52.83903, greedy 49.86833)
# rec 439.183 reg 0.094
# epoch 12150,loss 702.69418, epsilon 0.05000, rewards: ( e-greedy 52.50512, greedy 47.28149)
# rec 702.600 reg 0.094
# epoch 12160,loss 982.42350, epsilon 0.05000, rewards: ( e-greedy 54.50461, greedy 46.85334)
# rec 982.330 reg 0.094
# epoch 12170,loss 145.21159, epsilon 0.05000, rewards: ( e-greedy 52.55415, greedy 45.61801)
# rec 145.118 reg 0.094
# epoch 12180,loss 210.03428, epsilon 0.05000, rewards: ( e-greedy 51.54874, greedy 47.20621)
# rec 209.941 reg 0.094
# epoch 12190,loss 5036.56906, epsilon 0.05000, rewards: ( e-greedy 53.59386, greedy 48.28559)
# rec 5036.475 reg 0.094
# epoch 12200,loss 487.76997, epsilon 0.05000, rewards: ( e-greedy 54.23448, greedy 49.50703)
# rec 487.676 reg 0.094
# Learning curves:
# Random session examples
# epoch 12210,loss 273.46863, epsilon 0.05000, rewards: ( e-greedy 54.81103, greedy 51.85633)
# rec 273.375 reg 0.094
# epoch 12220,loss 228.11758, epsilon 0.05000, rewards: ( e-greedy 52.27993, greedy 51.67069)
# rec 228.024 reg 0.094
# epoch 12230,loss 958.71544, epsilon 0.05000, rewards: ( e-greedy 54.10193, greedy 50.80362)
# rec 958.622 reg 0.094
# epoch 12240,loss 490.92374, epsilon 0.05000, rewards: ( e-greedy 55.14174, greedy 52.47326)
# rec 490.830 reg 0.094
# epoch 12250,loss 226.05484, epsilon 0.05000, rewards: ( e-greedy 54.02757, greedy 53.97594)
# rec 225.961 reg 0.094
# epoch 12260,loss 370.67437, epsilon 0.05000, rewards: ( e-greedy 53.42481, greedy 54.72834)
# rec 370.581 reg 0.094
# epoch 12270,loss 355.09131, epsilon 0.05000, rewards: ( e-greedy 51.63233, greedy 54.25551)
# rec 354.997 reg 0.094
# epoch 12280,loss 1043.11225, epsilon 0.05000, rewards: ( e-greedy 53.06910, greedy 52.52996)
# rec 1043.018 reg 0.094
# epoch 12290,loss 314.44936, epsilon 0.05000, rewards: ( e-greedy 53.01219, greedy 50.92696)
# rec 314.356 reg 0.094
# epoch 12300,loss 530.72595, epsilon 0.05000, rewards: ( e-greedy 58.41097, greedy 52.53427)
# rec 530.632 reg 0.094
# Learning curves:
# Random session examples
# epoch 12310,loss 725.58701, epsilon 0.05000, rewards: ( e-greedy 58.31987, greedy 52.83084)
# rec 725.493 reg 0.094
# epoch 12320,loss 331.46035, epsilon 0.05000, rewards: ( e-greedy 58.03788, greedy 57.54775)
# rec 331.366 reg 0.094
# epoch 12330,loss 719.99895, epsilon 0.05000, rewards: ( e-greedy 57.88410, greedy 55.19298)
# rec 719.905 reg 0.094
# epoch 12340,loss 212.66819, epsilon 0.05000, rewards: ( e-greedy 55.19569, greedy 55.07368)
# rec 212.574 reg 0.094
# epoch 12350,loss 191.93444, epsilon 0.05000, rewards: ( e-greedy 52.92612, greedy 54.31631)
# rec 191.841 reg 0.094
# epoch 12360,loss 574.25532, epsilon 0.05000, rewards: ( e-greedy 53.88351, greedy 55.13468)
# rec 574.161 reg 0.094
# epoch 12370,loss 435.52565, epsilon 0.05000, rewards: ( e-greedy 54.19515, greedy 54.27121)
# rec 435.432 reg 0.094
# epoch 12380,loss 191.88458, epsilon 0.05000, rewards: ( e-greedy 53.22564, greedy 51.69409)
# rec 191.791 reg 0.094
# epoch 12390,loss 483.49912, epsilon 0.05000, rewards: ( e-greedy 54.10308, greedy 48.27468)
# rec 483.405 reg 0.094
# epoch 12400,loss 250.73599, epsilon 0.05000, rewards: ( e-greedy 52.04277, greedy 50.89721)
# rec 250.642 reg 0.094
# Learning curves:
# Random session examples
# epoch 12410,loss 144.57853, epsilon 0.05000, rewards: ( e-greedy 50.48849, greedy 51.60749)
# rec 144.485 reg 0.094
# epoch 12420,loss 944.00384, epsilon 0.05000, rewards: ( e-greedy 51.48964, greedy 51.04674)
# rec 943.910 reg 0.094
# epoch 12430,loss 649.50392, epsilon 0.05000, rewards: ( e-greedy 53.79068, greedy 55.34207)
# rec 649.410 reg 0.094
# epoch 12440,loss 255.69736, epsilon 0.05000, rewards: ( e-greedy 53.81161, greedy 55.50786)
# rec 255.603 reg 0.094
# epoch 12450,loss 1270.97439, epsilon 0.05000, rewards: ( e-greedy 53.43045, greedy 53.65708)
# rec 1270.880 reg 0.094
# epoch 12460,loss 196.63262, epsilon 0.05000, rewards: ( e-greedy 51.83740, greedy 52.59137)
# rec 196.539 reg 0.094
# epoch 12470,loss 684.16149, epsilon 0.05000, rewards: ( e-greedy 54.90366, greedy 55.38223)
# rec 684.067 reg 0.094
# epoch 12480,loss 263.55809, epsilon 0.05000, rewards: ( e-greedy 54.41330, greedy 52.84401)
# rec 263.464 reg 0.094
# epoch 12490,loss 1015.14011, epsilon 0.05000, rewards: ( e-greedy 56.32197, greedy 53.70961)
# rec 1015.046 reg 0.094
# epoch 12500,loss 315.83805, epsilon 0.05000, rewards: ( e-greedy 55.63977, greedy 52.03865)
# rec 315.744 reg 0.094
# Learning curves:
# Random session examples
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-85-c47f4d8860b7> in <module>()
# ----> 1 get_ipython().run_cell_magic(u'time', u'', u'\nn_epochs = 10000\n#25k may take hours to train.\n#consider interrupt early.\n\nfor i in range(n_epochs):    \n    #train\n    update_pool(env,pool,replay_seq_len)\n    resolver.rng.seed(i)    \n    loss,avg_reward = train_fun()\n    \n    \n    ##update resolver\'s epsilon (chance of random action instead of optimal one)\n    if epoch_counter%1 ==0:\n        current_epsilon = 0.05 + 0.45*np.exp(-epoch_counter/1000.)\n        resolver.epsilon.set_value(np.float32(current_epsilon))\n    \n    \n    \n    ##record current learning progress and show learning curves\n    if epoch_counter%10 ==0:\n\n        ##update learning curves\n        full_loss, q_loss, l2_penalty, avg_reward_current = evaluation_fun()\n        ma_reward_current = (1-alpha)*ma_reward_current + alpha*avg_reward_current\n        score_log["expected e-greedy reward"][epoch_counter] = ma_reward_current\n        \n        \n        \n        #greedy train\n        resolver.epsilon.set_value(0)\n        update_pool(env,pool,replay_seq_len)\n\n        avg_reward_greedy = evaluation_fun()[-1]\n        ma_reward_greedy = (1-alpha)*ma_reward_greedy + alpha*avg_reward_greedy\n        score_log["expected greedy reward"][epoch_counter] = ma_reward_greedy\n        \n        \n        #back to epsilon-greedy\n        resolver.epsilon.set_value(np.float32(current_epsilon))\n        update_pool(env,pool,replay_seq_len)\n\n        print("epoch %i,loss %.5f, epsilon %.5f, rewards: ( e-greedy %.5f, greedy %.5f) "%(\n            epoch_counter,full_loss,current_epsilon,ma_reward_current,ma_reward_greedy))\n        print("rec %.3f reg %.3f"%(q_loss,l2_penalty))\n\n    if epoch_counter %100 ==0:\n        print("Learning curves:")\n        score_log.plot()\n\n\n        print("Random session examples")\n        display_sessions()\n    \n    #run several sessions of game, record videos and save obtained results\n    if epoch_counter %1000 ==0:\n        \n        save_path = \'videos/MSPacman-v0_\' + str(epoch_counter)\n\n        subm_env = gym.make(GAME_TITLE)\n        subm_env = gym.wrappers.Monitor(subm_env, \'videos/\', force=True)\n\n        rws = []\n\n        for i_episode in xrange(10):\n\n            #initial observation\n            observation = subm_env.reset()\n            #initial memory\n            prev_memories = "zeros"\n\n            s_reward =0.\n            t = 0\n            while True:\n\n                action,new_memories = step([observation],prev_memories,batch_size=1)\n                observation, reward, done, info = subm_env.step(action[0])\n\n                s_reward += reward\n\n                prev_memories = new_memories\n                if done:\n                    print("Episode finished after {} timesteps, rw = {}".format(t+1,s_reward))\n                    rws.append(s_reward)\n                    break\n                t+=1\n\n        subm_env.close()\n\n        rws = np.array(rws)\n        print("Mean {}, Var {}".format(np.mean(rws), np.var(rws)))\n        np.savez(open(\'rws4hist_\'+str(epoch_counter)+\'.npz\', \'wb\'), rws=rws)\n        \n        \n    epoch_counter  +=1\n\n    \n# Time to drink some coffee!')
#
# /Users/vlad/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in run_cell_magic(self, magic_name, line, cell)
#    2113             magic_arg_s = self.var_expand(line, stack_depth)
#    2114             with self.builtin_trap:
# -> 2115                 result = fn(magic_arg_s, cell)
#    2116             return result
#    2117
#
# <decorator-gen-59> in time(self, line, cell, local_ns)
#
# /Users/vlad/anaconda2/lib/python2.7/site-packages/IPython/core/magic.pyc in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /Users/vlad/anaconda2/lib/python2.7/site-packages/IPython/core/magics/execution.pyc in time(self, line, cell, local_ns)
#    1178         else:
#    1179             st = clock2()
# -> 1180             exec(code, glob, local_ns)
#    1181             end = clock2()
#    1182             out = None
#
# <timed exec> in <module>()
#
# /Users/vlad/anaconda2/lib/python2.7/site-packages/theano/compile/function_module.pyc in __call__(self, *args, **kwargs)
#     871         try:
#     872             outputs =\
# --> 873                 self.fn() if output_subset is None else\
#     874                 self.fn(output_subset=output_subset)
#     875         except Exception:
#
# /Users/vlad/anaconda2/lib/python2.7/site-packages/theano/gof/op.pyc in rval(p, i, o, n)
#     858         if params is graph.NoParams:
#     859             # default arguments are stored in the closure of `rval`
# --> 860             def rval(p=p, i=node_input_storage, o=node_output_storage, n=node):
#     861                 r = p(n, [x[0] for x in i], o)
#     862                 for o in node.outputs:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Record videos

# %%
save_path = 'more_videos/MSPacman-v0_' + str(epoch_counter-1)

subm_env = gym.make(GAME_TITLE)
subm_env = gym.wrappers.Monitor(subm_env, 'more_videos/')

rws = []

for i_episode in xrange(220):

    #initial observation
    observation = subm_env.reset()
    #initial memory
    prev_memories = "zeros"

    s_reward =0.
    t = 0
    while True:

        action,new_memories = step([observation],prev_memories,batch_size=1)
        observation, reward, done, info = subm_env.step(action[0])

        s_reward += reward

        prev_memories = new_memories
        if done:
            print("Episode finished after {} timesteps, rw = {}".format(t+1,s_reward))
            rws.append(s_reward)
            break
        t+=1

subm_env.close()

rws = np.array(rws)
np.savez(open('rws5hist_'+str(epoch_counter-1)+'.npz', 'wb'), rws=rws)
# Out:
# [2017-05-23 15:49:56,853] Making new env: MsPacman-v0
# [2017-05-23 15:49:57,260] Starting new video recorder writing to /Users/vlad/Desktop/DL_SK/Project/more_videos/openaigym.video.12.72356.video000000.mp4
# /Users/vlad/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:11: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# [2017-05-23 15:50:01,715] Starting new video recorder writing to /Users/vlad/Desktop/DL_SK/Project/more_videos/openaigym.video.12.72356.video000001.mp4
# Episode finished after 978 timesteps, rw = 440.0
# Episode finished after 1069 timesteps, rw = 840.0
# Episode finished after 885 timesteps, rw = 250.0
# Episode finished after 1123 timesteps, rw = 500.0
# Episode finished after 944 timesteps, rw = 250.0
# Episode finished after 734 timesteps, rw = 170.0
# Episode finished after 1030 timesteps, rw = 240.0
# [2017-05-23 15:50:29,018] Starting new video recorder writing to /Users/vlad/Desktop/DL_SK/Project/more_videos/openaigym.video.12.72356.video000008.mp4
# Episode finished after 830 timesteps, rw = 440.0
# Episode finished after 894 timesteps, rw = 250.0
# Episode finished after 756 timesteps, rw = 440.0
# Episode finished after 828 timesteps, rw = 240.0
# Episode finished after 629 timesteps, rw = 100.0
# Episode finished after 889 timesteps, rw = 290.0
# Episode finished after 1092 timesteps, rw = 450.0
# Episode finished after 690 timesteps, rw = 110.0
# Episode finished after 828 timesteps, rw = 440.0
# Episode finished after 686 timesteps, rw = 70.0
# Episode finished after 943 timesteps, rw = 440.0
# Episode finished after 691 timesteps, rw = 110.0
# Episode finished after 921 timesteps, rw = 240.0
# Episode finished after 877 timesteps, rw = 440.0
# Episode finished after 1049 timesteps, rw = 440.0
# Episode finished after 862 timesteps, rw = 840.0
# Episode finished after 836 timesteps, rw = 440.0
# Episode finished after 875 timesteps, rw = 440.0
# Episode finished after 718 timesteps, rw = 110.0
# [2017-05-23 15:51:26,500] Starting new video recorder writing to /Users/vlad/Desktop/DL_SK/Project/more_videos/openaigym.video.12.72356.video000027.mp4
# Episode finished after 825 timesteps, rw = 290.0
# Episode finished after 1024 timesteps, rw = 240.0
# Episode finished after 1187 timesteps, rw = 450.0
# Episode finished after 1007 timesteps, rw = 840.0
# Episode finished after 913 timesteps, rw = 440.0
# Episode finished after 916 timesteps, rw = 250.0
# Episode finished after 737 timesteps, rw = 180.0
# Episode finished after 917 timesteps, rw = 240.0
# Episode finished after 690 timesteps, rw = 70.0
# Episode finished after 946 timesteps, rw = 440.0
# Episode finished after 738 timesteps, rw = 260.0
# Episode finished after 1073 timesteps, rw = 240.0
# Episode finished after 914 timesteps, rw = 440.0
# Episode finished after 887 timesteps, rw = 240.0
# Episode finished after 839 timesteps, rw = 840.0
# Episode finished after 826 timesteps, rw = 850.0
# Episode finished after 588 timesteps, rw = 170.0
# Episode finished after 923 timesteps, rw = 250.0
# Episode finished after 770 timesteps, rw = 520.0
# Episode finished after 842 timesteps, rw = 240.0
# Episode finished after 1069 timesteps, rw = 450.0
# Episode finished after 885 timesteps, rw = 520.0
# Episode finished after 1008 timesteps, rw = 440.0
# Episode finished after 842 timesteps, rw = 450.0
# Episode finished after 892 timesteps, rw = 840.0
# Episode finished after 861 timesteps, rw = 440.0
# Episode finished after 615 timesteps, rw = 110.0
# Episode finished after 1214 timesteps, rw = 380.0
# Episode finished after 948 timesteps, rw = 240.0
# Episode finished after 858 timesteps, rw = 250.0
# Episode finished after 1586 timesteps, rw = 240.0
# Episode finished after 879 timesteps, rw = 240.0
# Episode finished after 1023 timesteps, rw = 240.0
# Episode finished after 785 timesteps, rw = 440.0
# Episode finished after 986 timesteps, rw = 440.0
# Episode finished after 881 timesteps, rw = 520.0
# Episode finished after 916 timesteps, rw = 440.0
# [2017-05-23 15:53:19,569] Starting new video recorder writing to /Users/vlad/Desktop/DL_SK/Project/more_videos/openaigym.video.12.72356.video000064.mp4
# Episode finished after 1134 timesteps, rw = 240.0
# Episode finished after 748 timesteps, rw = 240.0
# Episode finished after 867 timesteps, rw = 440.0
# Episode finished after 815 timesteps, rw = 520.0
# Episode finished after 877 timesteps, rw = 440.0
# Episode finished after 1192 timesteps, rw = 520.0
# Episode finished after 1201 timesteps, rw = 440.0
# Episode finished after 727 timesteps, rw = 110.0
# Episode finished after 927 timesteps, rw = 250.0
# Episode finished after 1036 timesteps, rw = 440.0
# Episode finished after 904 timesteps, rw = 440.0
# Episode finished after 973 timesteps, rw = 440.0
# Episode finished after 865 timesteps, rw = 440.0
# Episode finished after 911 timesteps, rw = 290.0
# Episode finished after 839 timesteps, rw = 440.0
# Episode finished after 934 timesteps, rw = 1640.0
# Episode finished after 1095 timesteps, rw = 440.0
# Episode finished after 954 timesteps, rw = 440.0
# Episode finished after 862 timesteps, rw = 440.0
# Episode finished after 963 timesteps, rw = 840.0
# Episode finished after 963 timesteps, rw = 240.0
# Episode finished after 1030 timesteps, rw = 440.0
# Episode finished after 969 timesteps, rw = 300.0
# Episode finished after 959 timesteps, rw = 440.0
# Episode finished after 903 timesteps, rw = 240.0
# Episode finished after 1015 timesteps, rw = 450.0
# Episode finished after 924 timesteps, rw = 240.0
# Episode finished after 926 timesteps, rw = 450.0
# Episode finished after 799 timesteps, rw = 450.0
# Episode finished after 914 timesteps, rw = 440.0
# Episode finished after 901 timesteps, rw = 1730.0
# Episode finished after 916 timesteps, rw = 440.0
# Episode finished after 960 timesteps, rw = 450.0
# Episode finished after 893 timesteps, rw = 440.0
# Episode finished after 696 timesteps, rw = 100.0
# Episode finished after 880 timesteps, rw = 440.0
# Episode finished after 860 timesteps, rw = 240.0
# Episode finished after 936 timesteps, rw = 450.0
# Episode finished after 874 timesteps, rw = 250.0
# Episode finished after 1116 timesteps, rw = 490.0
# Episode finished after 900 timesteps, rw = 440.0
# Episode finished after 914 timesteps, rw = 250.0
# Episode finished after 914 timesteps, rw = 240.0
# Episode finished after 1004 timesteps, rw = 440.0
# Episode finished after 931 timesteps, rw = 240.0
# Episode finished after 879 timesteps, rw = 240.0
# Episode finished after 896 timesteps, rw = 240.0
# Episode finished after 778 timesteps, rw = 440.0
# Episode finished after 939 timesteps, rw = 240.0
# Episode finished after 849 timesteps, rw = 450.0
# Episode finished after 927 timesteps, rw = 240.0
# Episode finished after 925 timesteps, rw = 850.0
# Episode finished after 937 timesteps, rw = 850.0
# Episode finished after 947 timesteps, rw = 440.0
# Episode finished after 824 timesteps, rw = 440.0
# Episode finished after 929 timesteps, rw = 250.0
# Episode finished after 954 timesteps, rw = 240.0
# Episode finished after 814 timesteps, rw = 250.0
# Episode finished after 816 timesteps, rw = 440.0
# Episode finished after 942 timesteps, rw = 440.0
# Episode finished after 1065 timesteps, rw = 440.0
# [2017-05-23 15:56:35,704] Starting new video recorder writing to /Users/vlad/Desktop/DL_SK/Project/more_videos/openaigym.video.12.72356.video000125.mp4
# Episode finished after 893 timesteps, rw = 440.0
# Episode finished after 1041 timesteps, rw = 450.0
# Episode finished after 951 timesteps, rw = 240.0
# Episode finished after 942 timesteps, rw = 320.0
# Episode finished after 884 timesteps, rw = 240.0
# Episode finished after 854 timesteps, rw = 440.0
# Episode finished after 919 timesteps, rw = 850.0
# Episode finished after 689 timesteps, rw = 110.0
# Episode finished after 793 timesteps, rw = 240.0
# Episode finished after 860 timesteps, rw = 240.0
# Episode finished after 969 timesteps, rw = 440.0
# Episode finished after 883 timesteps, rw = 840.0
# Episode finished after 926 timesteps, rw = 440.0
# Episode finished after 974 timesteps, rw = 250.0
# Episode finished after 824 timesteps, rw = 440.0
# Episode finished after 848 timesteps, rw = 850.0
# Episode finished after 821 timesteps, rw = 240.0
# Episode finished after 1023 timesteps, rw = 440.0
# Episode finished after 825 timesteps, rw = 440.0
# Episode finished after 701 timesteps, rw = 70.0
# Episode finished after 899 timesteps, rw = 440.0
# Episode finished after 932 timesteps, rw = 240.0
# Episode finished after 1287 timesteps, rw = 490.0
# Episode finished after 940 timesteps, rw = 440.0
# Episode finished after 842 timesteps, rw = 450.0
# Episode finished after 994 timesteps, rw = 240.0
# Episode finished after 761 timesteps, rw = 440.0
# Episode finished after 889 timesteps, rw = 250.0
# Episode finished after 805 timesteps, rw = 440.0
# Episode finished after 981 timesteps, rw = 490.0
# Episode finished after 891 timesteps, rw = 240.0
# Episode finished after 1008 timesteps, rw = 240.0
# Episode finished after 882 timesteps, rw = 440.0
# Episode finished after 988 timesteps, rw = 250.0
# Episode finished after 931 timesteps, rw = 450.0
# Episode finished after 878 timesteps, rw = 450.0
# Episode finished after 870 timesteps, rw = 240.0
# Episode finished after 1223 timesteps, rw = 450.0
# Episode finished after 845 timesteps, rw = 440.0
# Episode finished after 1033 timesteps, rw = 440.0
# Episode finished after 1068 timesteps, rw = 240.0
# Episode finished after 1029 timesteps, rw = 450.0
# Episode finished after 900 timesteps, rw = 840.0
# Episode finished after 816 timesteps, rw = 840.0
# Episode finished after 832 timesteps, rw = 440.0
# Episode finished after 879 timesteps, rw = 440.0
# Episode finished after 1157 timesteps, rw = 240.0
# Episode finished after 884 timesteps, rw = 450.0
# Episode finished after 778 timesteps, rw = 240.0
# Episode finished after 974 timesteps, rw = 240.0
# Episode finished after 820 timesteps, rw = 240.0
# Episode finished after 904 timesteps, rw = 240.0
# Episode finished after 1199 timesteps, rw = 240.0
# Episode finished after 814 timesteps, rw = 450.0
# Episode finished after 848 timesteps, rw = 450.0
# Episode finished after 909 timesteps, rw = 240.0
# Episode finished after 826 timesteps, rw = 240.0
# Episode finished after 775 timesteps, rw = 290.0
# Episode finished after 1294 timesteps, rw = 280.0
# Episode finished after 1075 timesteps, rw = 240.0
# Episode finished after 784 timesteps, rw = 460.0
# Episode finished after 1067 timesteps, rw = 240.0
# Episode finished after 933 timesteps, rw = 250.0
# Episode finished after 1012 timesteps, rw = 250.0
# Episode finished after 757 timesteps, rw = 240.0
# Episode finished after 765 timesteps, rw = 450.0
# Episode finished after 1027 timesteps, rw = 440.0
# Episode finished after 887 timesteps, rw = 450.0
# Episode finished after 814 timesteps, rw = 1640.0
# Episode finished after 886 timesteps, rw = 520.0
# Episode finished after 777 timesteps, rw = 440.0
# Episode finished after 962 timesteps, rw = 450.0
# Episode finished after 870 timesteps, rw = 240.0
# Episode finished after 691 timesteps, rw = 110.0
# Episode finished after 1057 timesteps, rw = 240.0
# Episode finished after 809 timesteps, rw = 440.0
# Episode finished after 1272 timesteps, rw = 440.0
# Episode finished after 641 timesteps, rw = 130.0
# Episode finished after 1012 timesteps, rw = 840.0
# Episode finished after 808 timesteps, rw = 240.0
# Episode finished after 903 timesteps, rw = 440.0
# Episode finished after 906 timesteps, rw = 440.0
# Episode finished after 884 timesteps, rw = 440.0
# Episode finished after 706 timesteps, rw = 240.0
# Episode finished after 957 timesteps, rw = 500.0
# Episode finished after 599 timesteps, rw = 160.0
# Episode finished after 908 timesteps, rw = 240.0
# Episode finished after 686 timesteps, rw = 110.0
# Episode finished after 1068 timesteps, rw = 460.0
# Episode finished after 874 timesteps, rw = 440.0
# Episode finished after 785 timesteps, rw = 450.0
# [2017-05-23 16:01:18,903] Starting new video recorder writing to /Users/vlad/Desktop/DL_SK/Project/more_videos/openaigym.video.12.72356.video000216.mp4
# Episode finished after 928 timesteps, rw = 240.0
# Episode finished after 1009 timesteps, rw = 440.0
# Episode finished after 691 timesteps, rw = 70.0
# Episode finished after 874 timesteps, rw = 240.0
# [2017-05-23 16:01:30,476] Finished writing results. You can upload them to the scoreboard via gym.upload('/Users/vlad/Desktop/DL_SK/Project/more_videos')
# Episode finished after 863 timesteps, rw = 240.0

# %%
np.savez(open('greedy.npz', 'wb'), score_log['expected greedy reward'])
np.savez(open('egreedy.npz', 'wb'), score_log['expected e-greedy reward'])

# %% [markdown]
# ###### Patially used code: Aleksey Grinchuk (AlexGrinch), Mariya Popova (Mariewelt) ... and some hedgehog
